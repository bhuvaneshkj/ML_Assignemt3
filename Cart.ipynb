# %%
import pandas as pd
from sklearn import tree 
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics
from sklearn import preprocessing
from sklearn import metrics
import graphviz

# %%
train_df_1=pd.read_csv(r'C:\Users\chat2\OneDrive\Desktop\MachineLearning\HW-3\task_4_1_train.csv')

test_df_1=pd.read_csv(r'C:\Users\chat2\OneDrive\Desktop\MachineLearning\HW-3\task_4_1_test.csv')

train_df_2=pd.read_csv(r'C:\Users\chat2\OneDrive\Desktop\MachineLearning\HW-3\task_4_2_train.csv')

test_df_2=pd.read_csv(r'C:\Users\chat2\OneDrive\Desktop\MachineLearning\HW-3\task_4_2_test.csv')


train_df_2
# Out:
#      Outlook Temperature Humidity  Windy Label  id
# 0      Sunny         Hot     High  False    No   1
# 1      Sunny         Hot     High   True    No   2
# 2   Overcast         Hot     High  False   Yes   3
# 3      Rainy        Mild     High  False   Yes   4
# 4      Rainy        Cool   Normal  False   Yes   5
# 5      Rainy        Cool   Normal   True    No   6
# 6   Overcast        Cool   Normal   True   Yes   7
# 7      Sunny        Mild     High  False    No   8
# 8      Sunny        Cool   Normal  False   Yes   9
# 9      Rainy        Mild   Normal  False   Yes  10
# 10     Sunny        Mild   Normal   True   Yes  11
# 11  Overcast        Mild     High   True   Yes  12
# 12  Overcast         Hot   Normal  False   Yes  13
# 13     Rainy        Mild     High   True    No  14

# %%
train_df_encoded_1=pd.get_dummies(train_df_1,columns=['HomeOrAway','InOrOut','Media','Label'])
test_df_encoded_1=pd.get_dummies(test_df_1,columns=['HomeOrAway','InOrOut','Media'])
X_1=train_df_encoded_1.iloc[:,:-2]
Y_1=train_df_encoded_1.iloc[:,-1:]
X_1.shape
train_df_encoded_1.columns[:-2]
Y_1.columns
# Out:
# Index(['Label_Win'], dtype='object')

# %%
clf_g_1 = tree.DecisionTreeClassifier(criterion="gini")

# Train Decision Tree Classifer
clf_g_1 = clf_g.fit(X_1,Y_1)

# %%
y_pred_1 = clf.predict(test_df_encoded_1)
y_pred_1
# Out:
# array([0, 0, 1, 1, 1, 1], dtype=uint8)

# %%
dot_data = tree.export_graphviz(clf_g_1, out_file=None, 
                     feature_names=X_1.columns,  
                     class_names=['Win','Lose'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
train_df_encoded_2=pd.get_dummies(train_df_2,columns=['Outlook','Temperature','Humidity','Windy','Label'])
#test_df_encoded_2=pd.get_dummies(test_df_2,columns=['id','Temperature','Humidity','Windy'])
X_2=train_df_encoded_2.iloc[:,:-2]
Y_2=train_df_encoded_2.iloc[:,-1:]
# X_2.shape
# train_df_encoded_2.columns[:-2]
# Y_2.columns
# test_df_2
X_2
# Out:
#     id  Outlook_Overcast  Outlook_Rainy  Outlook_Sunny  Temperature_Cool  \
# 0    1                 0              0              1                 0
# 1    2                 0              0              1                 0
# 2    3                 1              0              0                 0
# 3    4                 0              1              0                 0
# 4    5                 0              1              0                 1
# 5    6                 0              1              0                 1
# 6    7                 1              0              0                 1
# 7    8                 0              0              1                 0
# 8    9                 0              0              1                 1
# 9   10                 0              1              0                 0
# 10  11                 0              0              1                 0
# 11  12                 1              0              0                 0
# 12  13                 1              0              0                 0
# 13  14                 0              1              0                 0
#
#     Temperature_Hot  Temperature_Mild  Humidity_High  Humidity_Normal  \
# 0                 1                 0              1                0
# 1                 1                 0              1                0
# 2                 1                 0              1                0
# 3                 0                 1              1                0
# 4                 0                 0              0                1
# 5                 0                 0              0                1
# 6                 0                 0              0                1
# 7                 0                 1              1                0
# 8                 0                 0              0                1
# 9                 0                 1              0                1
# 10                0                 1              0                1
# 11                0                 1              1                0
# 12                1                 0              0                1
# 13                0                 1              1                0
#
#     Windy_False  Windy_True
# 0             1           0
# 1             0           1
# 2             1           0
# 3             1           0
# 4             1           0
# 5             0           1
# 6             0           1
# 7             1           0
# 8             1           0
# 9             1           0
# 10            0           1
# 11            0           1
# 12            1           0
# 13            0           1

# %%
clf_g_2 = tree.DecisionTreeClassifier(criterion="gini")

# Train Decision Tree Classifer
clf_g_2 = clf_g.fit(X_2,Y_2)
X_2.shape
# Out:
# (14, 11)

# %%
y_pred_2 = clf_g_2.predict([[1,0,1,0,0,1,0,1,0,1,0]])
y_pred_2
# Out:
# array([0], dtype=uint8)

# %%
dot_data = tree.export_graphviz(clf_g_2, out_file=None, 
                     feature_names=X_2.columns,  
                     class_names=['Yes','No'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
graph
